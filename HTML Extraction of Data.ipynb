# %%
import pandas as pd

url = "https://fbref.com/en/comps/9/stats/Premier-League-Stats.html"

tables = pd.read_html(url)

neme = tables[0]

neme.to_csv("fb_2024_totals.csv", index=False)

# %%
neme
# Out:
#    Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                 Squad               # Pl                Age
# 0             Arsenal                 24               26.4
# 1         Aston Villa                 25               27.6
# 2         Bournemouth                 28               25.8
# 3           Brentford                 27               26.5
# 4            Brighton                 30               25.7
# 5             Chelsea                 27               24.1
# 6      Crystal Palace                 26               26.8
# 7             Everton                 24               29.1
# 8              Fulham                 25               28.5
# 9        Ipswich Town                 31               26.4
# 10     Leicester City                 28               27.2
# 11          Liverpool                 24               27.7
# 12    Manchester City                 26               27.8
# 13     Manchester Utd                 25               26.3
# ...
